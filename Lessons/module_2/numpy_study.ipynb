# %%
import numpy as np

# %%
a = np.array([1, 2, 3])
print(a)
# Out:
# [1 2 3]

# %%
b = np.array([[9, 0, 8], [6, 0, 5]])
print(b)
# Out:
# [[9 0 8]
#  [6 0 5]]

# %%
#Get Dimension
a.ndim
# Out:
# 1

# %%
#get shape
b.shape
# Out:
# (2, 3)

# %%
#get type
a.dtype
# Out:
# dtype('int64')

# %%
#get size
a.itemsize
# Out:
# 8
