# %%
class Food_info:
    def __init__(self, preferences, ingredients):
        self.preferences = preferences
        self.ingredients = ingredients
        pass

# %%
class User_Profile:
    def __init__(self, name, dietary_preference, weekly_budget):
        self.name = name
        self.dietary_preference = dietary_preference
        self.weekly_budget = weekly_budget

    file = open("user_profile.txt", "w")
    
    def file(self, filename= "user_profile.txt"):
        with open(filename, "w") as file:
            file.write(f"{self.name}")
            file.write(f"{self.dietary_preference}")
            file.write(f"{self.weekly_budget}")


        with open("user_profile.txt", "r") as file:
            content = file.read()
            print(content)

    # file = open("User Profile.txt", "r")
    # content = file.read()
    # print(content)
    # file.close()

# %%
#ingredient_storage
class Ingredient:
    def __init__(self, name, quantity):
        self.name = name
        self.quantity = quantity

Ingredient = []

file = open("ingredient.txt", "w")


def file(self, filename= "ingredient.txt"):
    with open(filename, "w") as file:
        file.write(f"{self.name}")
        file.write(f"{self.quantity}")

def load_ingredient():
    Ingredient = []
    
    with open("ingredient.txt", "r") as file:
        content = file.read()
        print(content)
        Ingredient.append(Ingredient(name, quantity))
    return Ingredient
