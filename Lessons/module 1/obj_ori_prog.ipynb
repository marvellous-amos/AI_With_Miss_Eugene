# %%
class Dog:
    species = "Canis familiaris"

    def __init__(self, name, age, breed):
        self.name = name
        self.age = age
        self.breed = breed

    #instance method
    def description(self):
        return f"{self.name} is {self.age} years old"
    #another instance method
    def speak(self, sound):
        return f"{self.name} says {sound}"

# %%
class Dog:
    pass
Dog()
Dog()
a = Dog()
b = Dog()
a == b
#pass is a placeholder indicating where code will eventually go
# Out:
# False

# %%
class Dog:
    species = "Canis familiaris"
    
    def __init__(self, name, age, breed):
        self.name = name
        self.age = age 
        self.breed = breed   
    def __str__(self):
        return f"{self.name} is {self.age} years old"  
    def speak(self, sound):
        return f"{self.name} says {sound}"

# %%
miles = Dog("Miles", 5, "Bulldog")
buddy = Dog("Buddy", 9, "Husky")
jack = Dog("Jack", 3, "Bulldog")
jim = Dog("Jim", 5, "Jack Russel")


miles.name
miles.age
buddy.species
# Out:
# 'Canis familiaris'

# %%
class Bulldog(Dog):
    pass

# %%
class Dog:
    species = "Canis familiaris"
    
    def __init__(self, name, age):
        self.name = name
        self.age = age  
    def __str__(self):
        return f"{self.name} is {self.age} years old"  
    def speak(self, sound):
        return f"{self.name} says {sound}"

# %%
miles = Bulldog("Miles", 5)

# %%
miles.speak("woof woof")
# Out:
# 'Miles says woof woof'

# %%
print(miles)
# Out:
# Miles is 5 years old

# %%
type(miles)
isinstance(miles, Dog)
# Out:
# True

# %%
miles.__str__()
# Out:
# 'Miles is 5 years old'

# %%
miles.speak("woof woof")
# Out:
# 'Miles says woof woof'

# %%
print(miles)

# %%
miles = Dog("Miles", 5)
print(miles)
# Out:
# Miles is 5 years old

# %%
class Car:
    pass
Car()
Car()
a = Car()
b = Car()
a == b
# Out:
# False

# %%
blue = Car("blue", 20000)
red = Car("red", 30000)

# %%
class Car:
    def __init__(self, color, milage):
        self.color = color
        self.milage = milage
    

    def __str__(self):
        return f"The {self.color} car has {self.milage:,} miles"

# %%
blue = Car("blue", 20000)
print(blue)
red = Car("red", 30000)
print(red)
# Out:
# The blue car has 20,000 miles
# The red car has 30,000 miles

# %%
class Dog:
    species = "Canis familiaris"
    
    def __init__(self, name, age):
        self.name = name
        self.age = age 

    def __str__(self):
        return f"{self.name} is {self.age} years old" 
     
    def speak(self, sound= "Bark"):
        return f"{self.name} barks:{sound}"

# %%
class Rotwellier(Dog):
    pass
    def speak(self, sound="Arf"):
        return super().speak(sound)

# %%
jale = Rotwellier("Jale", 6)
jale.speak("woof")
# Out:
# 'Jale barks:woof'
