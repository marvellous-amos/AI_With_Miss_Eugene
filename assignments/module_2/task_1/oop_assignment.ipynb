# %%
#user profile
class UserProfile:
    def __init__(self, user_name, dietary_preference, weekly_food_budget):
        self.user_name = user_name
        self.dietary_preference = dietary_preference
        self.weekly_food_budget = weekly_food_budget

    def __str__(self):
        return f"user_name: {self.user_name}\ndietary_preference: {self.dietary_preference}\nweekly_food_budget: {self.weekly_food_budget}"

# %%
#create an instance
user = UserProfile("Ibinabo", "Vegan", 50000)
user2 = UserProfile("Pearl", "Vegetarian", 30000)

#save to a text file
with open("user_profile.txt", "w") as file1:
    file1.write(str(user))

# %%
#ingredient storage
class Ingredient:
    def __init__(self, name, quantity):
        self.name = name
        self.quantity = quantity

    # def __str__(self):
    #     return f"name: {self.name}\nquantity: {self.quantity}"
    
ingredient1 = Ingredient("rice", "4 cups")
ingredient2 = Ingredient("tomato", "2 tins")

list_of_ingredients = []

list_of_ingredients.append(ingredient1)
list_of_ingredients.append(ingredient2)


    
# #create an instance
# jollof_rice = Ingredient(
#     name= ["rice", "tomatoes", "oil", "onions"],
#     quantity= ["4 cups", "2 tins", "1 litre", "2 bulbs"]
# )

#save to a text file
# with open("jollof_rice.txt", "w") as file2:
#     file2.write(str(jollof_rice))

# %%
print(len(list_of_ingredients))
# Out:
# 2

# %%
for x in list_of_ingredients:
    #add_ingredient(name, quantity)
    with open("jollof_rice.txt", "a") as file2:
        ingredient_details = f"{x.name},{x.quantity}\n"
        file2.write(ingredient_details)
        #list_of_ingredients

# %%
filename = "jollof_rice.txt"
new_item = ["bay leaves"]
with open(filename, "a") as file2:
    file2.write(f" {new_item}")
